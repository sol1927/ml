# %%
import tweepy

# Twitter API credentials
bearer_token = "AAAAAAAAAAAAAAAAAAAAAJw85wEAAAAAte5UZemZ65zZYK5hx%2Bxr1UJZ4xY%3DpEEYf8DxsFTUiL6Oymac0GGLT88KBSXtQ4vk07SMgJzu5a8oT8"
client = tweepy.Client(bearer_token=bearer_token)

# Search recent tweets
query = "Python -is:retweet lang:en"
tweets = client.search_recent_tweets(query=query, tweet_fields=['text'], max_results=100)

# Save only raw tweet text to a .txt file
with open("C:/Users/hp/Desktop/new/unstructured_tweets.txt", "w", encoding="utf-8") as f:
    for t in tweets.data:
        f.write(t.text + "\n")
# Out:
# Spark session started successfully!
# +-------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |created_at               |text                                                                                                                                                                                                                                                                                                |
# ...
