# %% [markdown]
# # Start spark session

# %%
# %run spark_session.py
# Out:
# Spark session started successfully!

# %% [markdown]
# # Data ingestion

# %%
# %run data_ingestion/ingest_structured.py

# %%
# %run data_ingestion/ingest_semistructured.py

# %% [markdown]
# # Build First ETL Pipeline

# %%
# %run ETL/ETL_structure.py

# %%
# %run ETL/ETL_semi.py

# %% [markdown]
# # Data cleaning

# %%
# %run clean_merge/clean_structure.py

# %%
# %run clean_merge/clean_semi.py

# %%
# %run clean_merge/create_col.py

# %% [markdown]
# # Merge

# %%
# %run clean_merge/merge_cleaned.py

# %%
# %run clean_merge/enrich_final_data.py
# Out:
# Writing final enriched dataset to HDFS...
# === SENTIMENT DISTRIBUTION ===
# +---------+-------+
# |sentiment|  count|
# +---------+-------+
# |  Neutral|1048380|
# | Positive|  86478|
# | Negative|  38659|
# +---------+-------+

# %% [markdown]
# # Store

# %%
# %run store_processed.py
# Out:
# Final processed dataset stored successfully!
# Saved to: hdfs://localhost:9000/processed/final_dataset

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
# %run eda.py

# %% [markdown]
# # Early BI visuals

# %%
# %run eda/eda_load.py

# %%
# %run eda/eda_missing.py

# %%
# %run eda/eda_text_top.py

# %%
# %run eda/eda_numeric_summary.py

# %%
# %run eda/eda_visuals.py

# %% [markdown]
# #  Submit Dashboard v1/Draft Report

# %%
# %run submit_dashboard/dashboard_report.py

# %%
# %run submit_dashboard/feature_engineering.py

# %% [markdown]
# # Train initial models

# %%
# %run ml/train_initial_models.py

# %% [markdown]
# # Evaluate performance

# %%
# %run ml/evaluate_models.py

# %% [markdown]
# # Comparision

# %%
# %run ml/comparision.py

# %% [markdown]
# # Finalize ML pipeline

# %%
# %run ml/final_pipeline.py
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\Desktop\ml\ml\final_pipeline.py:64
#      61     continue
#      63 # Show current prediction only
# ---> 64 result = predict_sentiment([user_input])
#      65 print("Type your text to predict sentiment. Type 'exit' to quit.\n")
#      66 print(f"Input: {result['Input'][0]}")
#
# File ~\Desktop\ml\ml\final_pipeline.py:34, in predict_sentiment(texts)
#      32 def predict_sentiment(texts):
#      33     X = vectorizer.transform(texts)
# ---> 34     predictions = model.predict(X)
#      36     pred_labels = [INT_TO_LABEL[p] for p in predictions]
#      38     return pd.DataFrame({
#      39         "Input": texts,
#      40         "Prediction": pred_labels,
#      41         "Prediction (int)": predictions
#      42     })
#
# ...

# %%
# %run ml/batch_sentiment_summary.py
